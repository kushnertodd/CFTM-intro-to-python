# %% [markdown]
# # Introduction to Python Programming
#
# This is to teach someone with no introduction to programming how to create and run Python programs.
# This will describe the kinds of instructions a Python program can run and how to write them.
# Before you begin, you will need to know:
# - How to use [Jupyter](https://jupyterlab.readthedocs.io/en/stable/)
# - The basic kinds of data, mainly [numbers and text](https://study.com/academy/lesson/data-types-in-programming-numbers-strings-and-others.html)
# - Some [basic math and arithmetic](https://www.khanacademy.org/math/arithmetic)
#
# Programs are a list of instructions to be followed by the computer, like a recipe.
# They are used for financial processing, scientific calculations, data science and any task that uses *data*, text or numbers.
# When you run a program, the computer will follow the instructions until it runs out of them or otherwise descides to stop.
# What makes computer programs useful is that they can repeat instructions many times and perform them quickly and accurately.
# The effort to write programs is repaid by automating work that is tedious and requires little skill.
# Programming uses a language that is unfamiliar, but to make it easier to learn it is *regular* in that it never varies and is not inconsistent like English.
#
# Programs perform many kinds of tasks, such as reading and writing data, and processing it with logic and calculations.
# These tasks involve many instructions, so programs use *functions* that collect a number of these instructions together to save time programming.
# Much of the effort learning to program is memorizing what these functions do and how to use them in programs.
#
# The following sections describe of basic types of data used in programs and useful functions to process them.
# The sections use knowledge from previous sections so you are meant to go through them one by one.
# When you are done, you will be able to write basic Python programs like the examples at the end.
#
# The Internet has a wealth of information to make programming easier and more effective.
# [python.org](python.org) and [w3schools.com](w3schools.com) are good sources of basic information on using Python.
# There are many useful [books](https://hackr.io/blog/best-python-books-for-beginners-and-advanced-programmers) on Python to use as references.
# Searching for the type of program you want to write and looking for examples you can use as samples can save you a lot of time programming.
# When you have an error you cannot understand, search for the error and you may find an explanation or solution on websites like [stackexchange.com](stackexchange.com) and [stackoverflow.com](stackoverflow.com).
#
# ## Printing
# The most basic way to print out data is `print`.
# You run this in Jupyter by clicking on the instruction below and typing `control-Enter`.

# %%
print("Hello world")
# Out:
# Hello world

# %% [markdown]
# `print` is a *function* that surrounds some *arguments* with parentheses `(` and `)` and separates them with commas `,`.
# A function collects the arguments and then runs some instructions that use the argument values.
# A function actually is a program that is used within a program, this will be covered later.

# %% [markdown]
# There are two ways to print: print text on a complete line like above, or print and stop in the middle of the line, and print the rest after.
# Run this to print text on separate lines.

# %%
print("Hello world. ")
print("Have a nice day.")
# Out:
# Hello world.
# Have a nice day.

# %% [markdown]
# Run this to print text twice on the same line.
# The `end=""` makes `print` stop without starting a new line.

# %%
print("Hello world. ", end="")
print("Have a nice day.")
# Out:
# Hello world. Have a nice day.

# %% [markdown]
# *Strings* are text that can be inside either two double quotes `"` or two single quotes `'`.
# The same quote starts and ends the string.

# %%
print("this is a double-quoted string")
print('this is a single-quoted string')
# Out:
# this is a double-quoted string
# this is a single-quoted string

# %% [markdown]
# If you need to put a double quote in a string, you can use a single-quoted string.
# If you need to put a single quote in a string, you can use a double-quoted string.

# %%
print("this is a double-quoted string with a single quote ' in it")
print('this is a single-quoted string with a double quote " in it')
# Out:
# this is a double-quoted string with a single quote ' in it
# this is a single-quoted string with a double quote " in it

# %% [markdown]
# ## Variables
# Programs pass values from instruction to instruction using *variables*.
# This stores 5 in a variable named `x` and prints it out.
#  `=` assigns 5 to the variable.

# %%
x = 5
print("x is ", x)
# Out:
# x is  5

# %% [markdown]
# The variable can be visualized like this, where `x` is a name for a place in which the value 5 is stored.

# %% [markdown]
# ![image](variable1.jpg)

# %% [markdown]
# Another way to print the variable `x` is with a *formatted string*, beginning with `f’` and ending with `'`.
# This prints out the value of the variable `x` in a formatted string, surrounding the variable `x` with `{` and `}`.
# Any Python value can be used between `{` and `}`. This can print a variable in a way that is more to your liking.

# %%
x = 5
print(f'the variable x has the data {x} inside it.')
# Out:
# the variable x has the data 5 inside it.

# %% [markdown]
# A variable can be assigned a  value and then be assigned to another  value to replace it it. This stores 5 in the variable `x`, and print it out.
# It then stores 7 in it and prints it out.

# %%
x = 5
print("first x is ", x)
x = 7
print("then x is ", x)
# Out:
# first x is  5
# then x is  7

# %% [markdown]
# This can be visualized like this, where `x` has the data 5 stored in it that is then replaced with the data 7, where `→` means "set to new value".

# %% [markdown]
# ![variable2.jpg](variable2.jpg)

# %% [markdown]
# A variable can also be assigned the value of another variable.
# This stores 5 in the variable `x`, then assigns the variable `y` to the value of `x`, and prints it out.

# %%
x = 5
y = x
print(f'x is {x} and y is {y}')
# Out:
# x is 5 and y is 5

# %% [markdown]
# ![image](variable3.jpg)

# %% [markdown]
# Variables can store text strings as well as numbers.
# This stores a string in the variable `s` and prints it out.

# %%
s = "Hello world. Have a nice day."
print(f'the text is "{s}"')
# Out:
# the text is "Hello world. Have a nice day."

# %% [markdown]
# ### A note on variable names
# Variable names start with a letter, `a` to `z` or `A` to `Z`, or `_`. They can have an `_` inside or at the beginning, but no other punctuation in them. They can have a number inside but not at the beginning. Capital and small letters matter, the variable name must always look exactly the same everywhere.

# %%
x = 2
x_y = 3
_x = 4
print(f'x is {x}, x_y is {3}, _x is {4}')
X = 5
x = 6
print(f'X is {X}, x is {x}')
# Out:
# x is 2, x_y is 3, _x is 4
# X is 5, x is 6

# %% [markdown]
# In the code here we will use different variable names for different types of data. They will be these:
# - `s`, `t`, `u`, `v`, and so on will have *string* values
# - `x`, `y`, `z`, and sometimes `n` will have number values

# %% [markdown]
# ## Data
# Numbers and strings are only two types of data in Python.
# Numbers and strings start as *literal constants* and are the most basic types of data in Python.
# `"hello"` and `5` are literal constants.
# Python instructions can combine these values with different *operations* on strings on numbers and can store them in variables.
# Instructions can use literal constants or can use those values stored in variables.
# Run this to add two values and store them in the variable `y`.

# %%
x = 5
y = x + 2
print(f'x is {x} and y is {y}')
# Out:
# x is 5 and y is 7

# %% [markdown]
# The sections below will show examples of operations available for these data types.
#
# ### Numbers
# Numbers in Python are either *integers*, which are signed whole numbers, and *real numbers* that have fractions.
# When you do arithmetic on them you can use either of the types.

# %%
x = 5 + 3.2
print(f'x is {x}')
# Out:
# x is 8.2

# %% [markdown]
# #### Number operators
# The usual arithmetic operators can be used, like addition `+` and subtraction `-`.
# You can do multiplication with `*` instead of `x` and division with `\` instead of $\div$.

# %%
x = (4 + 2 - 1) * 3.2
print(f'x is {x}')
x = x / 2.0
print(f'x is {x}')
# Out:
# x is 16.0
# x is 8.0

# %% [markdown]
# There are some special operators on numbers.
# To compute exponentials, like $3^2$:

# %%
x = 3**2
print(f'x is {x}')
# Out:
# x is 9

# %% [markdown]
# Another number operator is *modulo*, like "9 modulo 2", which gives the remainder after dividing 9 by 2.
# You can do a modulo operation with `%`.

# %%
x = 9 % 2
print(f'x is {x}')
# Out:
# x is 1

# %% [markdown]
# #### Operator shortcuts
# Some operators are used to change a variable's value, like `x = x + 1`.
# There is a shortcut for each of the operators for this.
# For `x = x + 1`, the shortcut is `x += 1`.
# There is a shortcut for `-`, `*`, `/`, `**`, and `%`.

# %%
x = 3
print(f'x starts as {x}')
x += 2
print(f'"x += 2" gives x as {x}')
x -= 1
print(f'"x -= 1" gives x as {x}')
x *= 4
print(f'"x *= 3" gives x as {x}')
x /= 4
print(f'"x /= 4" gives x as {x}')
x **= 2
print(f'"x **= 2" gives x as {x}')
x %= 3
print(f'"x %= 3" gives x as {x}')
# Out:
# x starts as 3
# "x += 2" gives x as 5
# "x -= 1" gives x as 4
# "x *= 3" gives x as 16
# "x /= 4" gives x as 4.0
# "x **= 2" gives x as 16.0
# "x %= 3" gives x as 1.0

# %% [markdown]
# #### `Abs` function
# The `abs` function takes a number that might be negative and gives the absolute value of it.

# %%
x = 3
y = -5
z = -4.3
print(f'abs({x}) is {abs(x)}.')
print(f'abs({y}) is {abs(y)}.')
print(f'abs({z}) is {abs(z)}.')
# Out:
# abs(3) is 3.
# abs(-5) is 5.
# abs(-4.3) is 4.3.

# %% [markdown]
# #### `Round` function
# The `round` function takes a real number and reduces the size of the fraction.
# It gives the integer value without the fraction if only the number is given as the argument.
# If a second argument is a number, that is the size of the fraction to keep.

# %%
x = 5.34
y = 9.2345
z = -8.431
print(f'round({x}) is {round(x)}.')
print(f'round({y}, 2) is {round(y, 2)}.')
print(f'round({z}) is {round(z)}.')
# Out:
# round(5.34) is 5.
# round(9.2345, 2) is 9.23.
# round(-8.431) is -8.

# %% [markdown]
# ### Strings
#
# Strings are text that can are made up of *characters*, which are letters, numbers, punctuation, and some special characters called *escape characters*.
# Strings have operations and functions that combine, remove, search, and replace for parts of text.

# %%
s = "Hello world. "
s = s + "Have a nice day."
print(f's is "{s}"')
# Out:
# s is "Hello world. Have a nice day."

# %% [markdown]
# #### Escape characters
# Escape characters are characters following a *backslash* character `\` in a string.
# The backslash gives a special meaning to the character that follows it.
# `\t` means the tab key on the keyboard, and `\n` is the enter key, called a *newline*.
# Because the backslash `\`  changes the meaning of the character that follows it, to really get a backslash you need to use `\\`.

# %%
print('this is the tab "\t" character')
print('this is the enter "\n" character')
print('this is the backslash "\\" character')
# Out:
# this is the tab "	" character
# this is the enter "
# " character
# this is the backslash "\" character

# %% [markdown]
# You can put a double quote in a double-quoted string by using backslash to escape it, an *escaped* double quote, that can go into a double-quoted string but not end the string.
# An escaped single quote can be put in a single-quoted string the same way.

# %%
print("this is a double-quoted string with a double quote \" in it")
print('this is a single-quoted string with a single quote \' in it')
# Out:
# this is a double-quoted string with a double quote " in it
# this is a single-quoted string with a single quote ' in it

# %% [markdown]
# Putting a single quote in the formatted string starting with `f'` and ending with a `'` needs an escaped single quote.

# %%
print(f'this is a formatted string with a single quote \' in it')
# Out:
# this is a formatted string with a single quote ' in it

# %% [markdown]
# #### Operations on strings
# Strings can be combined with the `+` add operator.
# The `+=` shortcut works as well.

# %%
s = "Again and "
s += "again ..."
print(f's is "{s}"')
# Out:
# s is "Again and again ..."

# %% [markdown]
# Strings can be repeated with the `*` multiplication operator.
# The `*=` shortcut works as well.

# %%
s = "hello " * 3
print(f's is "{s}"')
# Out:
# s is "hello hello hello "

# %% [markdown]
# #### Characters in strings
# Characters in strings can accessed with '[' and ']', where *string*`[`*position*`]` gives the character at *position* in the string.
# Python operators and functions count character positions from 0 rather than 1.
# The string can count *position* from the beginning of the string, or if *position* is negative, it can count from the back of the string.

# %%
s = "A red hat"
print("0123456789")
print("A red hat")
t = s[0]
u = s[3]
v = s[-1]
print(f's[0] is "{t}"')
print(f's[3] is "{u}"')
print(f's[-1] is "{v}"')
# Out:
# 0123456789
# A red hat
# s[0] is "A"
# s[3] is "e"
# s[-1] is "t"

# %% [markdown]
# #### Slices
# Strings that are part of other strings, *slices* or *substrings*, can be made from strings.
# The slice operator looks like *variable*`[`*start*`:`*end*`]` where the substring has all the characters from the character in the *start* position to the character *just before* the *end* position.
#
# A slice that has no *start* starts from the beginning of the string.
# A slice that has no *end* goes to the end of the string.

# %%
s = "A red hat"
print("0123456789")
print(f'{s}')
t = s[:1]
print(f'"{s}"[:1] is "{t}"')
t = s[2:5]
print(f'"{s}"[2:5] is "{t}"')
t = s[6:]
print(f'"{s}"[6:] is "{t}"')
# Out:
# 0123456789
# A red hat
# "A red hat"[:1] is "A"
# "A red hat"[2:5] is "red"
# "A red hat"[6:] is "hat"

# %% [markdown]
# #### `Len` function
# The `len` function gives the value of the string length.

# %%
s = "A red hat"
length = len(s)
print(f'the length of string "{s}" is {length}')
# Out:
# the length of string "A red hat" is 9

# %% [markdown]
# #### `Find` function
# The `find` function gives the first position where you can find a substring in a string.

# %%
s = "A red hat"
print("0123456789")
print(f'{s}')
x = s.find("red")
print(f'"red" is in "{s}" at position {x}')
# Out:
# 0123456789
# A red hat
# "red" is in "A red hat" at position 2

# %% [markdown]
# #### `Count` function
# The `count` function will count how many times a substring can be found in a string.

# %%
s = "the cat in the hat is at the store."
x = s.count("the")
y = s.count("at")
print(f'"the" is in "{s}" {x} times')
print(f'"at" is in "{s}" {y} times')
# Out:
# "the" is in "the cat in the hat is at the store." 3 times
# "at" is in "the cat in the hat is at the store." 3 times

# %% [markdown]
# #### `Upper` function
# The `upper` function makes all alphabet characters in a string into capitals.

# %%
s = "the cat in the hat is at the store"
t = s.upper()
print(f'"{s}" is "{t}" in capitals.')
# Out:
# "the cat in the hat is at the store" is "THE CAT IN THE HAT IS AT THE STORE" in capitals.

# %% [markdown]
# #### `Lower` function
# The `lower` function makes all alphabet characters  in a string into small letters.

# %%
s = "THE CAT IN THE HAT IS AT THE STORE"
t = s.lower()
print(f'"{s}" in "{t}" in small letters')
# Out:
# "THE CAT IN THE HAT IS AT THE STORE" in "the cat in the hat is at the store" in small letters

# %% [markdown]
# #### `Replace` function
# The `replace` function will find the substring of a string that matches a *pattern*, and replace it with another string.

# %%
s = "the red hat"
print(f'the string is "{s}"')
t = s.replace("red", "blue", 3)
print(f'the string with "red" replaced by "blue" is "{t}"')
# Out:
# the string is "the red hat"
# the string with "red" replaced by "blue" is "the blue hat"

# %% [markdown]
# #### `Str`, `Int`, and `Float` functions
# If you have a number but would like to use it as a string, the `str` method will make a string out of it.

# %%
x = 5
s = str(x)
y = 3.1
t = str(y)
print(f'{x} as a string is "{s}"')
print(f'{y} as a string is "{t}"')
# Out:
# 5 as a string is "5"
# 3.1 as a string is "3.1"

# %% [markdown]
# If you have a string but would like to use it as a number, the `int` function will make an integer out of it and the `float` function will make a real number out of it.

# %%
s = "5"
x = int(s)
stry = "3.1"
y = float(t)
t = str(y)
print(f'x is {x}')
print(f'y is {y}')
# Out:
# x is 5
# y is 3.1

# %% [markdown]
# #### `Input` function
# The `input` function can print a string on the console and wait for you to type some text, then give the text you typed as the value.

# %%
s = input('Enter some text: ')
print(f'The text you typed is "{s}"')

# %% [markdown]
# #### `Format` function
# The `format` function can make strings that look just the way you want.
# The `:3d` format will make a string out of an integer where the string is at least 3 characters wide, with spaces on the left if the integer is less than 3 characters long.

# %%
s ='{:3d}'.format(2)
t ='{:3d}'.format(65)
u ='{:3d}'.format(138)
v ='{:3d}'.format(4378)
print(f'"{s}" is the number 2 with format ":3d"')
print(f'"{t}" is the number 65 with format ":3d"')
print(f'"{u}" is the number 138 with format ":3d"')
print(f'"{v}" is the number 4378 with format ":3d"')

# %% [markdown]
# The `:<3d` format will make a string out of an integer where the string is at least 3 characters wide but with the number on the left if the integer is less than 3 characters long.

# %%
s ='{:<3d}'.format(2)
t ='{:<3d}'.format(65)
u ='{:<3d}'.format(138)
v ='{:<3d}'.format(4378)
print(f'"{s}" is the number 2 with format "<:3d"')
print(f'"{t}" is the number 65 with format "<:3d"')
print(f'"{u}" is the number 138 with format "<:3d"')
print(f'"{v}" is the number 4378 with format "<:3d"')

# %% [markdown]
# The `:^3d` format will make a string out of an integer where the string is at least 3 characters wide but with the number in the middle if the integer is less than 3 characters long.

# %%
s ='{:^3d}'.format(2)
t ='{:^3d}'.format(65)
u ='{:^3d}'.format(138)
v ='{:^3d}'.format(4378)
print(f'"{s}" is the number 2 with format "^:3d"')
print(f'"{t}" is the number 65 with format "^:3d"')
print(f'"{u}" is the number 138 with format "^:3d"')
print(f'"{v}" is the number 4378 with format "^:3d"')

# %% [markdown]
# For real numbers, the `:2f` format will make a string out of a real number where the string has up to 2 numbers in the fraction, with zeros on the left if the fraction of the real number has less than 2 digits.

# %%
s ='{:.2f}'.format(4)
t ='{:.2f}'.format(1.9)
u ='{:.2f}'.format(8.26)
print(f'"{s}" is the 4 with format ":.2f"')
print(f'"{t}" is the 1.9 with format ":.2f"')
print(f'"{u}" is the 8.26 with format ":.2f"')

# %% [markdown]
# For strings, he `:5s` format will make a string at least 5 characters wide but with spaces on the right if the string is less than 3 characters long.
# The `:>5s` will make the string at least 5 characters long but with spaces on the left, and `^5s` will make the string at least 5 characters long but in
# the center of the string.

# %%
s ='{:5s}'.format("one")
t ='{:>5s}'.format("one")
u ='{:^5s}'.format("one")
v ='{:^5s}'.format("eleven")
print(f'"{s}" is the "one" with format ":5s"')
print(f'"{t}" is the "one" with format ":>5s"')
print(f'"{u}" is the "one" with format ":^5s"')
print(f'"{v}" is the "eleven" with format ":5s"')

# %% [markdown]
# ## Compound Data Types
# There are *compound data types* that are collections of multiple data values that can be assigned to variables.
# These are *lists* and *dictionaries*, and are used to store things like grocery lists and telephone books that collect items of basic data types together.
#
# Variable names for compound data types will be:
# - `L`, `M`, `N`, and so on will be lists
# - `D`, `E`, `F`, and so on will be dictionaries

# %% [markdown]
# ### Lists
# The simplest compound data type are *lists*.
# Lists collect a series of other data type values in order between square brackets `[` and `]`.

# %%
L = [5, 9, 1]
print(f'L is {L}')

# %% [markdown]
# The list can be visualized like this.

# %% [markdown]
# ![list1.jpg](list1.jpg)

# %% [markdown]
# #### Operations on lists
# Lists can be combined with the `+` add operator.
# The `+=` shortcut works as well.

# %%
L = [5, 9, 10]
L = L + [4, 7]
print(f'L is {L}')
L += [1, 5]
print(f'L is {L}')

# %% [markdown]
# Lists can be repeated with the `*` multiplication operator.
# The `*=` shortcut works as well.

# %%
L = [1, 2] * 3
print(f'L is {L}')
L = [4, 5]
L *= 2
print(f'L is {L}')

# %% [markdown]
# #### Items in lists
# Each list item value can be accessed  with `[` and `]`, where *list*`[`*position*`]` gives the item at *position* in the list.
# Python operators and functions count item positions from 0 rather than 1.
# The list can count *position* from the beginning of the list or if *position* is negative, it can count from the back of the list.

# %%
L = [5, 9, 1]
x = L[0]
y = L[-2]
z = L[2]
print(f'first item of L {L} is {x}')
print(f'second item of L {L} is {y}')
print(f'third item of L {L} is {z}')

# %% [markdown]
# The value of an list item can be changed in the list by assigning an item with its position in square brackets `[` and `]`.
# Like before, positions start from 0.

# %%
L = [5, 9, 1]
print(f'L before changing is {L}')
L[0] = 4 
L[-2] = 6 
L[2] = 2 
print(f'L after changing is {L}')

# %% [markdown]
# #### Lists and variables
# There is not room to store the whole list in a variable, so the variable stores a *pointer* to the list.
# That can be visualized like this.

# %% [markdown]
# ![list2.jpg](list2.jpg)

# %% [markdown]
# When a list is assigned to a variable and that variable is assigned to another variable, the entire list isn't copied into the second variable.
# Only the *pointer* is copied.

# %% [markdown]
# ![list3.jpg](list3.jpg)

# %% [markdown]
# We can show that when both variables are pointing to the same list, when we change the list through the first variable we will see the change when looking through the second variable.

# %%
L = [5, 9, 1]
print(f'L starts as {L}.')
M = L
print(f'M after assigning from L is {M}.')
L[1] = 2
print(f'L after changing the second item to 2 is {L} and M is {M}.')

# %% [markdown]
# ![list4.jpg](list4.jpg)

# %% [markdown]
# #### `Copy` function
# To assign a list to another variable and be able to change the list through the second variable without affecting the first list, the `copy` function makes a copy of the list before assigning it to the second variable.
# Changing the second list then doesn't change the first list.

# %%
L = [5, 9, 1]
print(f'L starts as {L}.')
M = L.copy()
print(f'M after assigning from L is {M}.')
L[1] = 2
print(f'L after changing the second item to 2 is {L} and M is {M}.')

# %% [markdown]
# ![list5.jpg](list5.jpg)

# %% [markdown]
# #### Slices
# Lists that are part of other lists, *slices* or *sublists*, can be made from lists.
# The slice operator looks like *variable*`[`*start*`:`*end*`]` where the sublist are all the items from the item in the *start* position to the item *just before* the *end* position.
#
# A slice that has no *start* starts from the beginning of the list.
# A slice that has no *end* goes to the end of the list.

# %%
L = [5, 19, 1, 10, 8, 21]
print(f'L is {L}')
x = L[:1]
print(f'L[0:1] is {x}')
x = L[:3]
print(f'L[:3] is {x}')
x = L[4:]
print(f'L[4:] is {x}')

# %% [markdown]
# #### `Len` function
# The `len` function gives the list length.

# %%
L = [5, 9, 1]
x = len(L)
print(f'the length of L {L} is {x}')

# %% [markdown]
# #### `Append` function
# New items can be added at the end of the list with the `append` function.

# %%
L = [5, 9, 1]
print(f'L starts as {L}')
L.append(15)
print(f'L after adding 15 at the end is {L}')

# %% [markdown]
# #### `Insert` function
# Items can be added in the beginning or the middle of the list with the `insert` function.
# The position where the item is added is the first argument to `insert`, starting from 0, and the item to add is the second argument.
# All the items after the one added are moved down the list.

# %%
L = [5, 9, 1]
print(f'L starts as {L} and the length is {len(L)}. L[2] is {L[2]}.')
L.insert(1, 4)
print(f'L after adding 4 at position 1 is {L} and the length is {len(L)}. L[2] is {L[2]}.')

# %% [markdown]
# #### `Pop` function
# An item at some position can be removed with the `pop` function.
# The position of the item to remove is the first argument to `pop`, starting from 0.
# All items after the one removed are moved up the list.

# %%
L = [5, 9, 1]
print(f'L starts as {L} and the length is {len(L)}. L[1] is {L[1]}.')
L.pop(1)
print(f'L after removing the item at position 1 is {L} and the length is {len(L)}. L[1] is {L[1]}.')

# %% [markdown]
# #### `Remove` function
# The first item having some value can be removed from with the `remove` function.
# The value of the item to remove is the first argument to `remove`.
# Only the first item having the value will be removed.
# All items after the one removed are moved up the list.

# %%
L = [5, 9, 1, 9]
print(f'L starts as {L} and the length is {len(L)}')
L.remove(9)
print(f'L after removing the first item with value 9 is {L} and the length is {len(L)}.')
L.remove(9)
print(f'L after removing the second item with value 9 is {L} and the length is {len(L)}.')

# %% [markdown]
# #### `Extend` function
# A list can be added to the end of a list with the `extend` function, like the `+` operator.
# The list to add at the end of the first list is the argument to `extend`.

# %%
L = [5, 9, 1]
print(f'L starts as {L} and the length is {len(L)}')
M = [2, 4]
L.extend(M)
print(f'M is {M} and L after adding M to it is {L} and the length is {len(L)}.')

# %% [markdown]
# #### `Sum`, `Min`, `Max` functions
#
# Lists that are just numbers have functions to give the sum, minimum, and maximum.

# %%
L = [4, 1, 8, 2]
print(f'sum({L}) = {sum(L)}')
print(f'min({L}) = {min(L)}')
print(f'max({L}) = {max(L)}')

# %% [markdown]
# #### `Sort` function
# Lists can be sorted with the `sort` function into increasing number or alphabetic order.

# %%
L = [4, 1, 8, 2]
print(f'L before sort = {L}')
L.sort()
print(f'L after sort = {L}')
L = ["horse", "cat", "ox", "dog"]
print(f'L before sort = {L}')
L.sort()
print(f'L after sort = {L}')

# %% [markdown]
# #### `Reverse` function
# Lists items can be reversed with the `reverse` function.

# %%
L = [4, 1, 8, 2]
print(f'L before reverse = {L}')
L.reverse()
print(f'L after reverse = {L}')

# %% [markdown]
# #### Lists from strings: `Split` function
# Lists can be created from strings with the `split` function.
# Using `split` with no arguments splits a string at spaces.

# %%
s = "The cat in the hat"
L = s.split()
print(f'{s}.split() is {L}')

# %% [markdown]
# Strings can be split into lists where each item is separated by a string by giving a string to `split` as a second argument.

# %%
s = "first,second,third"
L = s.split(",")
print(f'{s}.split() is {L}')

# %% [markdown]
# #### Strings from lists: `join` function
# Strings can be created from list items by joining them together with a string.

# %%
L = ["first", "second", "third"]
print(f'" ".join({L}) is "{" ".join(L)}"')
L = ["O", "N", "E"]
print(f'"".join({L}) is "{"".join(L)}"')

# %% [markdown]
# ### Dictionaries
# *Dictionaries* are a compound data type similar to *lists*.
# In a dictionary you look up a value using another value rather than looking up a value by position like in a list.
# In a real dictionary, you look up a definition of a word using the word.
# The values have no order, but there is a value, called a *key*, associated with each value.

# %%
D = {"leaf": "green", "sky": "blue", "apple": "red"}
print(f'D is {D}')

# %% [markdown]
# The dictionary can be visualized like this.

# %% [markdown]
# ![dict1.jpg](dict1.jpg)

# %% [markdown]
# #### Items in dictionaries
# Each dictionary item can be accessed with '[' and ']', where *dictionary*`[`*key*`]` gives the value that has key *key* in the dictionary.

# %%
D = {"leaf": "green", "sky": "blue", "apple": "red"}
leaf = D["leaf"]
apple = D["apple"]
print(f'leaf item of {D} is {leaf}')
print(f'apple item of {D} is {apple}')

# %% [markdown]
# The value of a dictionary item can be changed in the dictionary by assigning an item with its key in square brackets `[` and `]`.

# %%
D["apple"] = "honeycrisp"
print(f'apple item of {D} after changing "apple" is "{D["apple"]}"')

# %% [markdown]
# New dictionary values can be created by assigning a value with a new key in square brackets `[` and `]`.

# %%
D = { "leaf": "green", "sky": "blue", "apple": "red"}
print(f'D before adding D["earth"] as "brown" is {D} length {len(D)}')
D["earth"] = "brown"
print(f'D after adding D["earth"] as "brown" is {D} length {len(D)}')

# %% [markdown]
# #### Dictionaries and variables
# There is not room to store whole dictionary in a variable, so the variable stores a *pointer* to the dictionary.
# That can be visualized like this.

# %% [markdown]
# ![dict2.jpg](dict2.jpg)

# %% [markdown]
# When a dictionary is assigned to a variable and that variable is assigned to another variable, the entire dictionary isn't copied into the second variable.
# Only the pointer is copied.

# %% [markdown]
# ![dict3.jpg](dict3.jpg)

# %% [markdown]
# We can show that when both variables are pointing to the same dictionary, when we change the dictionary through the first variable, and we will se the change looking through the second variable.

# %%
D = { "leaf": "green", "sky": "blue", "apple": "red"}
print(f'D starts as {D}.')
E = D
print(f'E after assigning from the first is {E}.')
D["apple"] = "yellow"
print(f'D after changing the "apple" value to "yellow" is {D} and E is {E}.')

# %% [markdown]
# ![dict4.jpg](dict4.jpg)

# %% [markdown]
# #### `Copy` function
# To assign a dictionary  to another variable and be able to change the dictionary through the second variable without affecting the first dictionary , the `copy` function makes a copy of the dictionary before assigning it to the second variable.
# Changing the second dictionary then doesn't change the first dictionary.

# %%
D = { "leaf": "green", "sky": "blue", "apple": "red"}
print(f'D starts as {D}.')
E = D.copy()
print(f'E after assigning from D is {E}.')
D["apple"] = "yellow"
print(f'D after changing the "apple" value to "yellow" is {D} and E is {E}.')

# %% [markdown]
# ![dict5.jpg ](dict5.jpg)

# %% [markdown]
# #### `Len` function
# The `len` function has the value of the dictionary length.

# %%
D = {"leaf": "green", "sky": "blue", "apple": "red"}
x = len(D)
print(f'the length of {D} is {x}')

# %% [markdown]
# #### `Keys` function
# The `keys` function gives a list of the dictionary keys.

# %%
D = {"leaf": "green", "sky": "blue", "apple": "red"}
L = D.keys()
print(f'the keys of {D} is {L}')

# %% [markdown]
# #### `Pop` function and `del` operator
# The `pop` function can remove an item from a dictionary.
# The key of the value to remove is the first argument to `pop`.
# The dictionary is one value smaller after `pop`.
# The `del` operator can remove an item too.

# %%
D = {"leaf": "green", "sky": "blue", "apple": "red"}
D.pop("leaf")
print(f'{D} after removing "leaf" is {D}')
del D["sky"]
print(f'{D} after removing "sky" is {D}')

# %% [markdown]
# ## Instruction control
#
# Programs may not want to run instructions just in the order they are given.
# You can run instructions only if something is true, repeat instructions while something is true, or for each item in a group.
# Examples are `if`, `while`, and `for` statements.
#
# ### `If` statements
# An `if` statement can run instructions if something is true.
# An `if` statement looks like:
#
#
# `if` *condition*`:` \
#  &nbsp;&nbsp;&nbsp;&nbsp;*some instruction* \
#  &nbsp;&nbsp;&nbsp;&nbsp;*another instruction* \
#  &nbsp;&nbsp;&nbsp;&nbsp;*and more...* \
# *instruction run after previous instructions*
#
# An `if` statment tests a *condition*, like `x < 5`, and if true runs the indented instructions after it.
# The next un-indented instruction is run whether or not the `if` *condition* is true.
# The indents have to be one or more spaces, and must be the same for each instruction.
# Here the first test is true and a line is printed.
# The second test is not true so no line is printed for that.
# The last line is always printed.

# %%
x = 5
if x > 3:
    print("x is more than 3")
if x < 2:
    print("x is less than 2")
print("after x tests")

# %% [markdown]
# ### Conditions
# Tests for `if` statements may use different operators or functions. An operator for a condition might be `>` in `x > 3`.
# In other cases a function might be used in the condition.

# %%
s = "hello"
if len(s) > 3:
    print(f'{s} is longer than 3')

# %% [markdown]
# #### Combining conditions
# Sometimes a condition might want to test more than one thing.
# An example is wanting a number to be between a lower and higher number.
# The `and` operator can do more than one test at a time.

# %%
x = 4
if x > 2 and x < 6:
    print(f'{x} is between 2 and 6')
if x > 5 and x < 9:
    print(f'{x} is between 5 and 9')

# %% [markdown]
# The `or` operator can test if either one test or another is true.
# Here the second test is true because when x is 4, it is less than 9 even if it is no more than 5.

# %%
x = 4
if x > 2 or x < 6:
    print(f'{x} is more than 2 or less than 6')
if x > 5 or x < 9:
    print(f'{x} is more than 5 or less than 9')

# %% [markdown]
# The `not` operator can test whether a condition is true or false to be the opposite.

# %%
x = 3
if x > 2:
    print('x {x} is greater than 2')
if not x < 1:
    print('x {x} is not less than 1')

# %% [markdown]
# #### Tests with numbers
#
# There are lots of conditions for numbers.
# Some of the operators are:
# - `==` tests if numbers are the same
# - `>` tests if a number is more than another
# - `<` tests if a number is less than another
# - `>=` tests if a number is the same or more than another
# - `<=` tests if a number is the same or less than another
# - `!=` tests if numbers are not the same

# %%
s = input("type a number to test:")
x = int(s)
if x == 3: 
    print("{x} is 3")
if x > 3: 
    print("{x} is greater than 3")
if x >= 3: 
    print("{x} is greater than or equal to 3")
if x < 3: 
    print("{x} is less than 3")
if x <= 3: 
    print("{x} is less than or equal to 3")
if x != 3: 
    print("{x} is not 3")

# %% [markdown]
# #### Tests with strings
# The `==` and `!=` operators can test whether strings are the same or different.
# Also, the `in` operator can test whether a string is part of another.

# %%
s = input(f'type a string to test against "test":')
t = "test"
if s == t: 
    print(f'"{s}" is "{t}"')
if s != t: 
    print(f'"{s}" is not "{t}"')    
if t in s: 
    print(f'"{s}" is part of "{t}"')

# %% [markdown]
# There a number of tests for the types of characters in a string using functions:
# - `isalpha(`*string*`)` tests whether all characters in a string are letters between "a" and "z" or between "A" and "Z"
# - `isdigit(`*string*`)` tests whether all characters in a string are numbers
# - `isalnum(`*string*`)` tests whether all characters in a string are numbers or letters
# - `isspace(`*string*`)` tests whether all characters in a string are spaces

# %%
s = input(f'type a string to test:')
if s.isalpha(): 
    print(f'"{s}" has all letters.')
if s.isdigit(): 
    print(f'"{s}" has all digits.')
if s.isalnum(): 
    print(f'"{s}" has all numbers or letters.')
if s.isspace(): 
    print(f'"{s}" has all spaces.')

# %% [markdown]
# #### Tests with lists
# The `in` operator tests if an item is in a list.

# %%
L = [1, 3, 9]
if 3 in L:
    print('3 is in {L}')

# %% [markdown]
# #### Tests with dictionary
# The `in` operator tests if a key is in a dictionary.

# %%
D = {"sky": "blue", "leaf": "green"}
if "sky" in D:
    print(f'"sky" is in {D}')

# %% [markdown]
# ### More on `if` statements
#
# You can test both whether a condition is true or false in one `if` statement with `else`.
# The instructions after the `if` are run if the condition is true and the instructions after `else` are run if the condition is not true.
#
# `if` *condition`:`\
# &nbsp;&nbsp;&nbsp;&nbsp;*instruction*\
# &nbsp;&nbsp;&nbsp;&nbsp;*instruction*\
# `else:`\
# &nbsp;&nbsp;&nbsp;&nbsp;*instruction*\
# &nbsp;&nbsp;&nbsp;&nbsp;*instruction*

# %%
s = input(f'type a string to test:')
if s.isalpha(): 
    print(f'isalpha("{s}") are all letters.')
else: 
    print(f'isalpha("{s}") is not all letters.')

# %% [markdown]
# You can test a number of conditions in one `if` statement with `elif`.
# `elif` lets you test one condition after another.
# The instructions after the `if` are run if the condition is true and runs the instructions after the first `elif` when that condition is true.
# There can be an `else` at the end that runs if none of the conditions are true.
#
# `if` *condition*`:`\
# &nbsp;&nbsp;&nbsp;&nbsp;*instruction*\
# &nbsp;&nbsp;&nbsp;&nbsp;*instruction*\
# `elif` *condition*`:`\
# &nbsp;&nbsp;&nbsp;&nbsp;*instruction*\
# &nbsp;&nbsp;&nbsp;&nbsp;*instruction*\
# `elif` *condition*`:`\
# &nbsp;&nbsp;&nbsp;&nbsp;*instruction*\
# &nbsp;&nbsp;&nbsp;&nbsp;*instruction*\
# `else:`\
# &nbsp;&nbsp;&nbsp;&nbsp;*instruction*\
# &nbsp;&nbsp;&nbsp;&nbsp;*instruction*

# %%
s = input("type a number to test:")
x = int(s)
if x > 9: 
    print("{x} is greater than 9")
elif x >= 3: 
    print("{x} is between 3 and 9")
else: 
    print("{x} is less than 3")

# %% [markdown]
# ### `While` loop
# `if` statements let you run some instructions one time if some condition is true.
# `while` statements let you run some instructions multiple times until a condition is true.
# A while loop looks like:
#
# `while` *condition*`:`\
# &nbsp;&nbsp;&nbsp;&nbsp;*instruction*\
# &nbsp;&nbsp;&nbsp;&nbsp;*instruction*\
#
# There is one catch: the condition has to use some variables, and the instructions have to change value of the variables so that at some time the condition becomes false.
# Otherwise the program will run those instructions forever.
# In this loop, `i` starts below 6, but goes up 1 each time so that it eventually becomes 6 and the loop stops.

# %%
x = 2
while x < 6:
    print(f'x is {x}')
    x += 1

# %% [markdown]
# This `while` loop can convert pounds to kilograms until you enter 0.

# %%
s = ""
while s != "0":
    s = input("give the number of pounds to convert to kilograms, type 0 to stop:")
    x = int(s)
    print(f'{x} pounds is {x * 2.2} kilograms')

# %% [markdown]
# ### `For` loop
#
# The `for` loop is like a `while` loop except that it runs instructions once for each item in a group.
# Two types of groups that can be used can be the characters in a string or items in a list.
# A `for` loop looks like:
#
# `for` *item* `in` *group*`:`\
# &nbsp;&nbsp;&nbsp;&nbsp;*instruction*\
# &nbsp;&nbsp;&nbsp;&nbsp;*instruction*
#
# The variable name `i` will be used for the item used in a `for` loop.

# %%
print("a for loop for a string")
s = "abcd"
for c in s:
    print(f'the next character of "{s}" is "{c}"')
    s = "abcd"
print("a for loop for a list")
L = ["first", "second", "third"]
for i in L:
    print(f'the next word in "{L}" is "{i}"')

# %% [markdown]
# ### `Range` function
# `for` loops often run for each number in a group of numbers.
# The `range` function creates a list of numbers for the `for` loop to run on.
# A `for` loop using `range(n)` with one argument loops through the numbers `0` to `n-1`.

# %%
for i in range(4):
    print(f'the next number in range(4) is {i}')

# %% [markdown]
# Using `range(m, n)` with two arguments will loop through the numbers `m` to `n-1`.

# %%
for i in range(2, 5):
    print(f'the next number in range(2, 5) is {i}')

# %% [markdown]
# Using `range(m, n, step)` can add `step` each time until the number is more than `n-1`.

# %%
for i in range(3, 9, 2):
    print(f'the next number in range(3, 9, 2) is {i}')

# %% [markdown]
# Using `range(m, n, -1)` the loop can count down from `m` to `n+1`.

# %%
for i in range(5, 2, -1):
    print(f'the next number in range(5, 2) is {i}')

# %% [markdown]
# ## List comprehensions

# %% [markdown]
# Lists can be made using `for` loops.
# A *list comprehension* has a `for` loop inside `[` and `]` to create the items in a list.
# List comprehensions look like:
#
# `[`*formula* `for` *variable* `in` *group*`]`
#
# where the *formula* gives a value using the *variable* and the *variable* has the value of each item in the group.

# %%
L = [i for i in range(5)]
print(f'"[i for i in range(5)]" produces {L}')
L = [2*i for i in range(5)]
print(f'"[2*i for i in range(5)]" produces {L}')
L = [c for c in "abc"]
print(f'"[c for c in "abc"]" produces {L}')

# %% [markdown]
# If the formula does not use the variable, the list will just repeat the value of the formula.

# %%
L = [1 for i in range(5)]
print(f'"1 for i in range(5)" produces {L}')

# %% [markdown]
# List comprehensions can make creating many different kinds of lists easier because any formula or `for` loop can be used.

# %% [markdown]
# ## Dictionary comprehensions
#
# Dictionaries can be made using `for` loops.
# A *dictionary comprehension* has a `for` loop inside `{` and `}` to create the items in a dictionary.
# Dictionary comprehensions look like:
#
# `[`*key-formula*: *value-formula* `for` *variable* `in` *group*`]`
#
# where the *key-formula* gives a value for the key and the *value-formula*  gives the key value using the *variable*, and the *variable* has the value it would have in a `for` loop for the item in the group.

# %%
keys = ["sky", "leaf"]
values = ["blue", "green"]
colors = {keys[i]: values[i] for i in range(len(keys))}
print(f'dictionary comprehension of {keys} and {values} produce {colors}')
# Out:
# dictionary comprehension of ['sky', 'leaf'] and ['blue', 'green'] produce {'sky': 'blue', 'leaf': 'green'}

# %% [markdown]
# Dictionary comprehensions can make creating many different kinds of dictionaries easier because any formula or `for` loop can be used.

# %% [markdown]
# ## Functions
# When a group of instructions need to be used many times in programs, *functions* save time in programming.
# Functions can take values as *arguments*, and return values if needed.
# Many functions are available in Python for many tasks.
# Functions are defined with `def`.
# These are examples of functions with no arguments and with arguments, and that return values or just run instructions.

# %%
def hello():
    print("hello")
def print_this(s):
    print(s)
def increase(x):
    return x+1
print(f'hello() does this:')
hello()
print(f'print_this("hello") does this:')
print_this("hello")
print(f'increase(5) gives this: {increase(5)}')

# %% [markdown]
# Variables inside a function only matter inside the function.
# Variables with the same name inside a function and in the instructions that call them are different.

# %%
def variable_test():
    print(f'   in variable_test:')
    x = 3
    print(f'   x at the start of variable_test is {x}')
    x = 4
    print(f'   x at the end of variable_test is {x}')
x = 5
print(f'x before calling variable_test is {x}')
variable_test()
print(f'x after calling variable_test the first time is {x}')
variable_test()
print(f'x after calling variable_test the second time is {x}')

# %% [markdown]
# ## Regular Expressions
# *Regular expressions* are *patterns* that match parts of strings.
# A regular expression can tell if a string matches a pattern.
#
# The variable name `p` will be used to store patterns.

# %%
import re
s = "this needs to be matched"
p = "match"
if re.search(p, s):
    print(f'pattern "{p}" matches string "{s}"')

# %% [markdown]
# A pattern is made of normal string keyboard characters and escape characters, but some characters and escape characters have special meaning in patterns.
# - period `.` matches any character
# - the escape character `\.` is needed to match a period, because a period has a special meaning
# - the escape character `\d` matches any number character, or *digit*, 0 to 9
# - the escape character `\D` is the opposite of `\d` and matches anything that is not a digit
# - the escape character `\w` matches any digit or alphabet character a to z, or A to Z
# - the escape character `\W` is the opposite of `\w` and matches anything that is not a digit or alphabet character
# - the escape character `\s` matches any *space character* which are spaces `" "`, tabs `\t`, or newlines `\n`
# - the escape character `\S` is the opposite of `\s` and matches anything that is not a space character

# %%
import re
s = "there are 12 months in the year"
p = "\d\d"
if re.search(p, s):
    print(f'pattern "{p}" matches string "{s}"')

# %% [markdown]
# There are special characters that control how characters match in a pattern.
# - plus `+` means the normal character or escape character just before it will match one or more of that character in the string
# - star `*` means the normal character or escape character just before it will match zero or more of that character in the string
# - question mark `?` means the normal character or escape character just before it will match if that character is in the string but will still match if it is missing
# - caret `^` at the beginning of the pattern means the pattern must match starting at the beginning of the string
# - dollar sign `$` at the end of the pattern means the pattern must matsh ending at the end of the string
# - to match a plus, star, question mark, caret, or dollar sign, the escape character version must be used, `\+`, `\*`. `\?`, `\^`, or `\$`

# %%
import re
s = "there are 12 months in the year"
p = "\d+"
if re.search(p, s):
    print(f'pattern "{p}" matches string "{s}"')

# %% [markdown]
# The pattern to match a date like '*month*/*day*/*year*, where month and day are two digits like "03/05/2011", is `\d\d/\d\d/\d\d\d\d`, where the `\d` are escape characters and slash `/` matches a normal slash.

# %%
import re
s = "03/05/2011"
p = "\d\d/\d\d/\d\d\d\d"
if re.search(p, s):
    print(f'pattern "{p}" matches the string "{s}"')

# %% [markdown]
# There are special characters to control how many times characters will match in a pattern.
# - `{`*count*`}` will match the character just before it *count* times
# - `{`*min-count*`,`*max-count*`}` will match the character just before it at least *min-count* times but at most *max-count* times
# The pattern to match a date can be `\d{2}/\d{2}/\d{4}` this way.

# %%
import re
s = "03/05/2011"
p = "\d{2}/\d{2}/\d{4}"
if re.search(p, s):
    print(f'pattern "{p}" matches the string "{s}"')

# %% [markdown]
# Groups of characters and escape characters can match together using `(` and `)`.

# %%
import re
s = "banana"
p = "(an){2}"
if re.search(p, s):
    print(f'pattern "{p}" matches string "{s}"')

# %% [markdown]
# The `|` can be used in a group inside `(` and `)` to let either of two patterns to match.

# %%
import re
p = "a (long|short) day"
s = "this has been a long day"
if re.search(p, s):
    print(f'pattern "{p}" matches string "{s}"')
    p = "a (long|short) day"
s = "this has been a short day"
if re.search(p, s):
    print(f'pattern "{p}" matches string "{s}"')

# %% [markdown]
# When you match a pattern with escape characters, you can get the exact part of the string matched with the `group` function.

# %%
import re
s = "today 03/05/2011 is March 5th, 2011"
p = "\d{2}/\d{2}/\d{4}"
m = re.search(p, s)
if m:
    print(f'the string matched by pattern "{p}" in the string "{s}" is "{m.group()}"')

# %% [markdown]
# By grouping parts of the pattern with `(` and `)`, the `group` function can give the part of the string matched by each group.

# %%
import re
s = "on 03/05/2011 it rained"
p = "(\d{2})/(\d{2})/(\d{4})"
m = re.search(p, s)
if m:
    print(f'the string matched by pattern "{p}" in the string "{s}" is "{m.group()}"')
    print(f'the month of "{m.group()}" is "{m.group(1)}"')
    print(f'the day ofs "{m.group()}" is "{m.group(2)}"')
    print(f'the year of "{m.group()}" is "{m.group(3)}"')

# %% [markdown]
# ## Files
# Files hold data that programs use.
# - Programs can read data from files
# - Programs can write data to files
# - Programs can add data to files that already are there
#
# ### `Open` and `Close` functions
# The `open` function gets a program ready to read or write a file.
# - `open(`*file-name*`)` gets the program ready to read a file
# - `open(`*file-name*`, 'w')` gets the program ready to write a file
# - `open(`*file-name*`, 'a')` gets the program ready to add to a file that already exists
#
# `open` returns a *file descriptor* used to read or write to the file.
# The `close` function is used complete reading or writing to a *file descriptor*.
#
# The variable names `f`, `g`, and so on will be used for file descriptors.

# %%
f = open("file.txt")

# %% [markdown]
# Files in these examples will have lines of text data.
# This file will hold this.
# ```
# 05/20/2021 $20.11 Office supplies
# 12/01/2021 $123.11 Desk chair
# 06/14/2021 $50.82 Telephone bill
# ```
# This will read the file lines and print them out.
# The `strip` function makes the printing more readable.

# %%
f = open("file.txt", "r")
for s in f:
  print(s.strip())
f.close()

# %% [markdown]
# # Examples
# These are examples of programs that put together what we've learned.
#
# ## File processing example
# This example uses regular expressions to add the cost of items in the file.
# These are regular expressions to pull out the date, cost, and name of supplies.
# - date `(\d{2})/(\d{2})/(\d{4})`
# - cost `\$(\d+\.\d+)` where `\$` and `\.` are escaped characters because `$` and `.` are special characters
# - name of supplies `(.*)` where `.*` matches all the text after the cost
#
# `import re` is needed to start using regular expressions.

# %%
import re
p = "(\d{2}/\d{2}/\d{4}) \$(\d+\.\d+) (.*)"
f = open("file.txt", "r")
total = 0.0
for line in f:
    m = re.search(p, line)
    print()
    print(line.strip())
    if m:
        date = m.group(1)
        cost = m.group(2)
        name = m.group(3)
        total += float(cost)
        print(f'date {date} cost ${cost} name "{name}"')
    else:
        print("    line is not the right format")
f.close()
print()
print(f'total cost: ${total}')
# Out:
# 05/20/2021 $20.11 Office supplies
# date 05/20/2021 cost $20.11 name "Office supplies"
#
# 12/01/2021 $123.11 Desk chair
# date 12/01/2021 cost $123.11 name "Desk chair"
#
# 06/14/2021 $50.82 Telephone bill
# date 06/14/2021 cost $50.82 name "Telephone bill"
#
# total cost: $194.04

# %% [markdown]
# <!--
# # Examples
# - dictionary example
# sum based on type
# - objects
# tree/list class
# - state machine
# delete duplicates
# -->

# %% [markdown]
# ## Sorting a list
# The `sort` function can sort lists, but understanding how it works is a good example for programming.
# Suppose we have a list we want to sort from lowest to highest.

# %% [markdown]
# ![sort1.jpg](sort1.jpg)

# %% [markdown]
# One way to sort the list is to start at the bottom and move the lowest number to the top.

# %% [markdown]
# ![sort2.jpg](sort2.jpg)

# %% [markdown]
# The lowest number is now at the top. Next start at the bottom of the list and move the second highest number to be second in the list.

# %% [markdown]
# ![sort3.jpg](sort3.jpg)

# %% [markdown]
# The top two items are now sorted. Next is to move the third highest number to be the third in the list.
# Now because the top three items are sorted, the fourth item is in the right spot, and the whole list is sorted.

# %% [markdown]
# ![sort4.jpg](sort4.jpg)

# %% [markdown]
# The way we program this is to say what we want to do in English first.
#
# - Start with a list *n* long
# - Let the lowest item *bubble* up to the top of the list
# - Let the next lowest item bubble up to the second item in the list
# - Repeat this until we bubble the second highest number to the second-to-the-last item in the list
#
# We compare the last item in the list to the one above it, and swap them  if the last item is less.
# We do this until we compare the second item in the list to the first item in the list.
# We then compare the last item in the list to the one above it, and swap them if the last item is less.
# We compare and swap items until we compare to the second item in the list.
# This says that bubble up to the top of the list, to the second item of the list, until we compare to the second-to-the-last item in the list, or *n-1* times, because there are n-1 items between the top and the second-to-the-last item.
#
# We want a program that looks like this:
# ```
# sort(L):
#   n = len(L)
#   for i in 1 to n-1: (we bubble the lowest item to the top, then the second, down to the second-to-last spot in the list)
#     from j = n (the last item) to i-1 (the spot below the one we're bubbling to)
#       compare the item at j to the item at j-1
#       swap them if the item at j is less than the item at j-1
# ```
# That is about it, except shifting the spots in the list because lists positions start at 0, not 1. Here is the program as a function, with some prints to track what it's doing.

# %%
def sort(L):
    n = len(L)
    print(f'the length of {L} is {n}')
    for i in range(n-1):
        print(f'  bubbling the next lowest item to the position {i}')
        for j in range(n-1, i, -1):
            print(f'    comparing the item at position {j} = {L[j]} to the one at position {j-1} = {L[j-1]}')
            if (L[j] < L[j-1]):
                print(f'      swapping the item at position {j} = {L[j]} to the one at position {j-1} = {L[j-1]}')
                x = L[j]
                L[j] = L[j-1]
                L[j-1] = x
        print(f'The list at round {i} is {L}')
    
sort([9, 3, 8, 1])
print(f'The final list is {L}')

# %% [markdown]
# The final list matches our diagram. The steps to write this program were:
# - coming up with a small test case that shows how the program works
# - thinking out an idea of how the program might work, here the key was *bubbling* the lowest element to it's right position each time
# - making a diagram of steps as the program runs
# - writing the idea in English in a way that the steps are understandable
# - writing the Python instructions, printing out variables at various steps as the program runs
#
# One way this program would be useful is that what we define as *lower* items might be more complicated than *the number value of the item is less*.
# The items might be strings, or *less* might be that a "mouse" might be less than a "rabbit", a "rabbit" might be less than a "dog", and so forth.
# We would change the comparison `L[j] < L[j-1]` to our own comparison to test if an item is *less* than another.
# We saw how `for` loops can control the bubbling, and that a small program can sort a list of any size.

# %% [markdown]
# ## Searching in a sorted list
# We often need to find something in a long list of things, like in a phone book, dictionary, or address list. We can design a small test case of a list with 12 items.

# %% [markdown]
# ![search1.jpg](search1.jpg)

# %% [markdown]
# Now we come up with an idea for the program. Searching up the list from the first to the 11th position is the obvious one. This is an example of thinking about *cases*. As we look up the list, there are three cases that can occur:
# 1. We find the item
# 1. We see an item larger than number, in which case we stop looking
# 1. We reach the end of the list
#
# Case 2. shows that because the list is sorted, we save some time if the number is missing because if we look at a list item that is larger, we know the number can't be in the list.

# %%
L = [1, 3, 4, 7, 10, 11, 14, 18, 21, 23, 26]
length = len(L)
print(f'The list to search is {L}')
x = int(input("give the number to search for"))
i = 0
while i < length and L[i] < x:
    i += 1
if i >= length or L[i] != x:
    print(f'could not find {x} in {L} after looking at {i+1} items')
else:
    print(f'found {x} is at position {i+1} of {L} after looking at {i+1} items')
# Out:
# The list to search is [1, 3, 4, 7, 10, 11, 14, 18, 21, 23, 26]
# give the number to search for 27
# could not find 27 in [1, 3, 4, 7, 10, 11, 14, 18, 21, 23, 26] after looking at 12 items

# %% [markdown]
# We look for the item with a `while` loop based on the cases above. We will search the list from the start to the end using `i` as the item to look at, counting positions from `0` to `length - 1`.
# - case 1: if `L[i] == x`, we find the item in `i` tries
# - case 2: if `l[i] > x`, we can stop looking after `i` tries because it can't be in the rest of the list
# - case 3: if `i >= length`, we've run off the end of the list after `length` tries
#
# Because of case 2., we will save some time because the list is sorted since we only have to search up to the first list item `L[i] >= x`, because if `L[i] == x` we found the number and if `L[i] > x` the list items are all larger and we can stop looking.
#
# It is always good to come up with some solution. If we have time, we can look for a better one.
# Here we can think of how to use the fact that the list is sorted.
# If we look somewhere in the list, we have three cases:
# - case 1: the list item is equal to the number
# - case 2: the list item is less than the number
# - case 3: the list item is greater than the number
#
# Because the list is sorted, we can see the next thing to do:
# - case 1: we found the number
# - case 2: the number is above the list item in the list
# - case 3: the number is below the list item in the list
#
# There are two subcases to case 2.:
# - case 2a: the number is above the list item and the list item is the last in the list
# - case 2b: the number is above the list item and there are more list items above the list item
#
# There are two subcases to case 3.:
# - case 3a: the number is below the list item and the list item is the first in the list
# - case 3b: the number is below the list item and there are more list items below the list item
#
# In case 2a and case 3a there are no more list items to look at so we don't find the number.
# Now we can look at some diagrams of how the program might run.
#
# We can say we are looking for the number 7 in our list above. Let's say we look in the middle of the list first, at item 5, halfway between the bottom at item 0 and the top at item 10.

# %% [markdown]
# ![search2.jpg](search2.jpg)

# %% [markdown]
# If the middle list item is 7, we have found it and we are done.
# In this case, the middle list item is 11, and we can know to look below in the list, which is case 3.

# %% [markdown]
# ![search3.jpg](search3.jpg)

# %% [markdown]
# The bottom of the list below it is still list item 0 and the top of the list below it is at list item 4, just under the middle before at list item 5.
# We next look at the middle of this list which is at list item `(4+1)/2 = 2`. This list item is 4, and because the number 7 is more than this, it is in the list above it, which is case 2.

# %% [markdown]
# ![search4.jpg](search4.jpg)

# %% [markdown]
# Now the bottom is at list item 3, just above the middle before, and the top is still at list item 4. The middle is at list item `(3 + 4) / 2 = 3.5`, which is 3 if we round down. The number 7 is at list item 3 so we have found it, which is case 1.

# %% [markdown]
# ![search5.jpg](search5.jpg)

# %% [markdown]
# ## Data cleaning: removing duplicate lines in a file

# %% [markdown]
# A common task in Data Science if cleaning data in files. In this example we have a file with duplicate lines, and we want to remove the duplicates so we just have unique lines in the file. In this case we have a sample data file with some duplicate lines. The program idea is that we look at the *previous line* to decide if a line is a duplicate:
# - case 1: the previous line is the same, then the current line is a duplicate
# - case 2: the previous line is not the same, then the current line is new and should be kept (printed back out)
#
# We then see there are two more cases:
# - case 3: the first line in the file. There is no previous line, so the current line is new and should be kept.
# - case 4: we run out of lines in the file. There is no current line, so there is nothing we have to do.
#
# We can see in this case that:
# - the first line is A, line 0 (we always count from 0, this is case 3 so we print it
# - the second line, line 1, is B, this is case 2 so we print it
# - the third line, line 2, is B, this is case 1 and we ignore it
# - the fourth line, line 3, is C, this is case 2 so we print it
# - the fifth line, line 4, is D, this is case 2 so we print it
# - the sixth line, line 4, is D, this is case 1 so we ignore it

# %% [markdown]
# ![duplicate1.jpg](duplicate1.jpg)

# %% [markdown]
# We can now write the program. `last` is the last line we saw. `first` tells us whether we are at the first line of the file, which is case 3. We read all the lines of the file, and don't need to do anything at the end, just close the file.
#
# Let's say the file `duplicates.txt` is this:
# ```
# A
# B
# B
# C
# D
# D
# ```
# This is the program. `strip` is used because the line actually has a `newline`, "\n", at the end which we can ignore.
# The line beginning with `#` is a *comment*.
# It is for notes we make to about what the program is doing, it is ignored when the program runs.
# The first time we read a line, `first` is `True`, we have case 3 and we print the line.
# We use `elif` to test the line after the first is read and `first` is set to `False`.
# If the test is true, the line is different from the last and we have case 2, and we print the line.
# If the test is false, the line is the same as the last and we have case 1, and we ignore the line.

# %%
first = True
f = open("duplicates.txt", "r")
for line in f:
    current = line.strip()
    if first:
        first = False
        last = current
        print(current)
    elif current != last:
        print(current)
    # otherwise, if current == last it is a duplicate and we ignore it
    last = current
f.close()
# Out:
# A
# B
# C
# D

# %% [markdown]
# ## Computing a square root
#
# Python has a `sqrt` function to compute a square root of a number.

# %%
import math
x = int(input('Give the number you want the square root of:'))
print(f'the square root of {x} is {math.sqrt(x)}')

# %% [markdown]
# `sqrt` is one of the functions Python supplies for tasks needed by many programs to save us time programming. `import math` says we will use the `math` *module* where a module is a group of functions Python is making available. We call `math.sqrt` to tell Python that `sqrt` is part of the `math` module.
#
# We can compute the square root ourselves by using a formula.
# If we make a *guess* of the square root and divide the number by it, when the guess is right we will get the same number back.

# %%
x = 9
y = 9/3
print(f'making a guess that 3 is the square root of {x}, the result of dividing {x} by 3 is {y}')

# %% [markdown]
# What if the guess is wrong? If the guess is less than the actual square root, the value after dividing by the number must be more than the guess.

# %%
x = 9
y = 9/2
print(f'making a guess that 2 is the square root of {x}, the result of dividing {x} by 2 is {y}')

# %% [markdown]
# We'll try an idea for the program.
# - If we have a number, we make a guess and divide it into the number.
# - If the guess and the result of dividing it into the number are the same, we've found the square root.
# - If they are not the same, we can try a new guess that is the number halfway between the guess and the result.
#
# The number halfway between two numbers is the average, or $first-number + second-number / 2$.

# %%
x = 9
y = 2
z = x/y
print(f'dividing {x} by 2 gives {y}, and the average of the two is {(y + z) / 2}')

# %% [markdown]
# Our idea is that the next guess is closer to the real square root.
# Now we might think if we tried that a few times, we'd be close to the square root.
# We will try this a number of times in a `for` loop, and for now just try running it 5 times.
# We'll also use some different variable names to try to keep track of things better.
# We'll try half of the number as the first guess.

# %%
import math
x = int(input('Give the number you want the square root of:'))
guess = x / 2
for i in range(5):
    x_divided_by_guess = x / guess
    next_guess = (guess + x_divided_by_guess) / 2
    print(f'the guess is {guess} and {x} divided by the guess is {x_divided_by_guess}. the next guess is the average of the two which is {next_guess}')
    guess = next_guess
print(f'the square root from math.sqrt({x}) is {round(math.sqrt(x), 4)}')

# %% [markdown]
# This was not too bad.
# 5 tries got us to the square root.
# For a larger number, it might take more guesses.
# We'll try giving both the number and the number of times to try.

# %%
import math
x = int(input('Give the number you want the square root of:'))
n = int(input('Give the number of tries to get the square root:'))
guess = x / 2
for i in range(n):
    x_divided_by_guess = x / guess
    next_guess = (guess + x_divided_by_guess) / 2
    print(f'the guess is {round(guess, 4)}, and the average with {round(x_divided_by_guess, 4)} is {round(next_guess, 4)}')
    guess = next_guess
print(f'the square root from math.sqrt({x}) is {round(math.sqrt(x), 4)}')

# %% [markdown]
# Our program can give the square root of any number by letting us put in however many tries we need to get the guess to be right.
# Try a large number and see how many tries it takes.
# It usually won't take that many.
# The program did not take many instructions.

# %% [markdown]
# ## Plotting example
# Here is an example using mathplotlib

# %%
#%matplotlib notebook
# %matplotlib inline

import matplotlib.pyplot as plt
#import seaborn as sns

#from numpy import random
#from scipy.ndimage.filters import gaussian_filter

#x = random.randn(10,500)
#x = gaussian_filter(x, [0, 10])
#sns.lineplot(data=x.T,dashes=False,legend=None);


#%matplotlib widget
#import ipywidgets as widgets
#import matplotlib.pyplot as plt
#import numpy as np
names = ['group_a', 'group_b', 'group_c']
values = [1, 10, 100]

plt.figure(figsize=(9, 3))

plt.subplot(131)
plt.bar(names, values)
plt.subplot(132)
plt.scatter(names, values)
plt.subplot(133)
plt.plot(names, values)
plt.suptitle('Categorical Plotting')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 get_ipython().run_line_magic('matplotlib', 'widget')
#       2 import ipywidgets as widgets
#       3 import matplotlib.pyplot as plt
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\IPython\core\interactiveshell.py:2294, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2292     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2293 with self.builtin_trap:
# -> 2294     result = fn(*args, **kwargs)
#    2295 return result
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\IPython\core\magics\pylab.py:99, in PylabMagics.matplotlib(self, line)
#      97     print("Available matplotlib backends: %s" % backends_list)
#      98 else:
# ---> 99     gui, backend = self.shell.enable_matplotlib(args.gui.lower() if isinstance(args.gui, str) else args.gui)
#     100     self._show_matplotlib_backend(args.gui, backend)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\IPython\core\interactiveshell.py:3444, in InteractiveShell.enable_matplotlib(self, gui)
#    3423 def enable_matplotlib(self, gui=None):
#    3424     """Enable interactive matplotlib and inline figure support.
#    3425
#    3426     This takes the following steps:
#    (...)
#    3442         display figures inline.
#    3443     """
# -> 3444     from matplotlib_inline.backend_inline import configure_inline_support
#    3446     from IPython.core import pylabtools as pt
#    3447     gui, backend = pt.find_gui_and_backend(gui, self.pylab_gui_select)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib_inline\backend_inline.py:6, in <module>
#       1 """A matplotlib backend for publishing figures via display_data"""
#       3 # Copyright (c) IPython Development Team.
#       4 # Distributed under the terms of the BSD 3-Clause License.
# ----> 6 import matplotlib
#       7 from matplotlib.backends.backend_agg import (  # noqa
#       8     new_figure_manager,
#       9     FigureCanvasAgg,
#      10     new_figure_manager_given_figure,
#      11 )
#      12 from matplotlib import colors
#
# ModuleNotFoundError: No module named 'matplotlib'
